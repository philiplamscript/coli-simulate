# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings('ignore')

# %%
def coli_fight2(score1,score2,true_score1,true_score2):
    #def prob
    prob = np.clip((true_score1-true_score2)/200 + 0.6,0,1)
    #result on score
    result = np.random.rand()
    if result < prob: #att win
        return score1+20,score2-10
    else:
        return score1-10,score2+20
def my_floor(a, precision=0):
    return np.round(a - 0.5 * 10**(-precision), precision)
    
def data_create(n,rank,ture_rank,type):
    return pd.DataFrame({'score':np.repeat(rank,n),'true score':np.repeat(ture_rank,n),'skiped time':np.repeat(0,n),
    'att count':np.repeat(0,n),'def count':np.repeat(0,n),'att win':np.repeat(0,n),'def win':np.repeat(0,n),
    'type':np.repeat(type,n),'play_time':np.random.choice(20,n),
    #'meta':np.random.choice(3,n),
    })
def data_createII(n,rank,ture_rank,type):
    return pd.DataFrame({'score':np.repeat(rank,n),'true score':np.repeat(ture_rank,n),'skiped time':np.repeat(0,n),
    'att count':np.repeat(0,n),'def count':np.repeat(0,n),'att win':np.repeat(0,n),'def win':np.repeat(0,n),
    'type':np.repeat(type,n),'play_time':np.repeat(20,n),
    #'meta':np.random.choice(3,n),
    })
#type 0:regular,1:not play at all,2:skip first five,3:speaical study no apply logic in script
